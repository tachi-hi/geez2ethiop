# %%
# !pip install -q git+https://github.com/tachi-hi/geez2ethiop.git

# %%
from geez2ethiop import ethiop2ipa, geez2ethiop

# %%
print(geez2ethiop("አዲስ አበባ"))
# Out:
# 'adise 'ababA

# %%
print(ethiop2ipa(geez2ethiop("አዲስ አበባ")))
# Out:
# '\"adis\textschwa{} '\"ab\"aba
